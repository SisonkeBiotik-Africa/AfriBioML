# %% [markdown]
# #Loading the Keyword Data

# %%
#Calling libraries
import urllib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Retrieving files
urllib.request.urlretrieve("https://raw.githubusercontent.com/SisonkeBiotik-Africa/AfriBioML/main/CSV/refinedkeywords_final.csv", "refinedkeywords_final.csv")
# Out:
# ('refinedkeywords_final.csv', <http.client.HTTPMessage at 0x7f5b9549e0a0>)

# %%
#Creating dataframes
df = pd.read_csv("refinedkeywords_final.csv", sep=";")

# %%
df.shape
# Out:
# (46292, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46292 entries, 0 to 46291
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Keyword          46292 non-null  object
#  1   Class            46292 non-null  object
#  2   EID              46292 non-null  object
#  3   Year             46292 non-null  int64
#  4   Highly Cited     46292 non-null  bool
#  5   North Africa     46292 non-null  bool
#  6   OA               46292 non-null  bool
#  7   Journal Article  46292 non-null  bool
# dtypes: bool(4), int64(1), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# #Keyword mentions per class

# %%
df["Class"].value_counts().plot(kind='bar');

# %% [markdown]
# #Main keywords per class

# %%
df["Class"].unique()
# Out:
# array(['computer science', 'medicine', 'other', 'biology', 'demography',
#        'mathematics and statistics', 'anatomy', 'engineering',
#        'psychology and sociology', 'science', 'education', 'chemistry',
#        'physics', 'environment'], dtype=object)

# %%
df[df["Class"] == "computer science"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "medicine"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "other"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "biology"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "demography"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "mathematics and statistics"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "anatomy"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "engineering"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "psychology and sociology"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "science"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "education"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "chemistry"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "physics"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %%
df[df["Class"] == "environment"]["Keyword"].value_counts()[0:30].plot(kind="bar");

# %% [markdown]
# #Class mentions and condition

# %%
df.groupby(['Class'])['Highly Cited'].value_counts(normalize=True).mul(100).round(1).unstack(level=1).plot(kind='barh', stacked=True);

# %%
df.groupby(['Class'])['North Africa'].value_counts(normalize=True).mul(100).round(1).unstack(level=1).plot(kind='barh', stacked=True);

# %%
df.groupby(['Class'])['OA'].value_counts(normalize=True).mul(100).round(1).unstack(level=1).plot(kind='barh', stacked=True);

# %%
df.groupby(['Class'])['Journal Article'].value_counts(normalize=True).mul(100).round(1).unstack(level=1).plot(kind='barh', stacked=True);

# %%
df["After 2020"] = df["Year"] >= 2020
df.groupby(['Class'])['After 2020'].value_counts(normalize=True).mul(100).round(1).unstack(level=1).plot(kind='barh', stacked=True);

# %% [markdown]
# #Keyword per class and condition

# %%
def keywordpercondition(classname, condition):
  best = df[df["Class"] == classname]["Keyword"].value_counts()[0:30].index.tolist()
  best.reverse()
  df[df["Class"] == classname].groupby(['Keyword'])[condition].value_counts(normalize=True).loc[best,:].mul(100).round(1).unstack(level=1).plot(kind='barh', stacked=True);

# %%
keywordpercondition("computer science", "Highly Cited")

# %%
keywordpercondition("computer science", "North Africa")

# %%
keywordpercondition("computer science", "OA")

# %%
keywordpercondition("computer science", "Journal Article")

# %%
keywordpercondition("computer science", "After 2020")

# %%
keywordpercondition("medicine", "Highly Cited")

# %%
keywordpercondition("medicine", "North Africa")

# %%
keywordpercondition("medicine", "OA")

# %%
keywordpercondition("medicine", "Journal Article")

# %%
keywordpercondition("medicine", "After 2020")

# %%
keywordpercondition("other", "Highly Cited")

# %%
keywordpercondition("other", "North Africa")

# %%
keywordpercondition("other", "OA")

# %%
keywordpercondition("other", "Journal Article")

# %%
keywordpercondition("other", "After 2020")

# %%
keywordpercondition("biology", "Highly Cited")

# %%
keywordpercondition("biology", "North Africa")

# %%
keywordpercondition("biology", "OA")

# %%
keywordpercondition("biology", "Journal Article")

# %%
keywordpercondition("biology", "After 2020")

# %%
keywordpercondition("demography", "Highly Cited")

# %%
keywordpercondition("demography", "North Africa")

# %%
keywordpercondition("demography", "OA")

# %%
keywordpercondition("demography", "Journal Article")

# %%
keywordpercondition("demography", "After 2020")

# %%
keywordpercondition("mathematics and statistics", "Highly Cited")

# %%
keywordpercondition("mathematics and statistics", "North Africa")

# %%
keywordpercondition("mathematics and statistics", "OA")

# %%
keywordpercondition("mathematics and statistics", "Journal Article")

# %%
keywordpercondition("mathematics and statistics", "After 2020")

# %%
keywordpercondition("anatomy", "Highly Cited")

# %%
keywordpercondition("anatomy", "North Africa")

# %%
keywordpercondition("anatomy", "OA")

# %%
keywordpercondition("anatomy", "Journal Article")

# %%
keywordpercondition("anatomy", "After 2020")

# %%
keywordpercondition("engineering", "Highly Cited")

# %%
keywordpercondition("engineering", "North Africa")

# %%
keywordpercondition("engineering", "OA")

# %%
keywordpercondition("engineering", "Journal Article")

# %%
keywordpercondition("engineering", "After 2020")

# %%
keywordpercondition("psychology and sociology", "Highly Cited")

# %%
keywordpercondition("psychology and sociology", "North Africa")

# %%
keywordpercondition("psychology and sociology", "OA")

# %%
keywordpercondition("psychology and sociology", "Journal Article")

# %%
keywordpercondition("psychology and sociology", "After 2020")

# %%
keywordpercondition("science", "Highly Cited")

# %%
keywordpercondition("science", "North Africa")

# %%
keywordpercondition("science", "OA")

# %%
keywordpercondition("science", "Journal Article")

# %%
keywordpercondition("science", "After 2020")

# %%
keywordpercondition("education", "Highly Cited")

# %%
keywordpercondition("education", "North Africa")

# %%
keywordpercondition("education", "OA")

# %%
keywordpercondition("education", "Journal Article")

# %%
keywordpercondition("education", "After 2020")

# %%
keywordpercondition("chemistry", "Highly Cited")

# %%
keywordpercondition("chemistry", "North Africa")

# %%
keywordpercondition("chemistry", "OA")

# %%
keywordpercondition("chemistry", "Journal Article")

# %%
keywordpercondition("chemistry", "After 2020")

# %%
keywordpercondition("physics", "Highly Cited")

# %%
keywordpercondition("physics", "North Africa")

# %%
keywordpercondition("physics", "OA")

# %%
keywordpercondition("physics", "Journal Article")

# %%
keywordpercondition("physics", "After 2020")

# %%
keywordpercondition("environment", "Highly Cited")

# %%
keywordpercondition("environment", "North Africa")

# %%
keywordpercondition("environment", "OA")

# %%
keywordpercondition("environment", "Journal Article")

# %%
keywordpercondition("environment", "After 2020")
